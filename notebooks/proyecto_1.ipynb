# %% [markdown]
# # Proyecto 1 · Obtención y Limpieza de Datos
#
# **Curso:** CC3084 · Data Science
# **Estado:** Cuaderno inicial
#
# Este cuaderno contiene únicamente el esqueleto del proyecto.
# Aún no se han descargado ni limpiado datos.

# %% [markdown]
# ## 0. Dependencias y configuración

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

RAW_DIR = Path("../data/raw")
INTERIM_DIR = Path("../data/interim")
PROCESSED_DIR = Path("../data/processed")
FIGURES_DIR = Path("../reports/figures")

for directory in [RAW_DIR, INTERIM_DIR, PROCESSED_DIR, FIGURES_DIR]:
    directory.mkdir(parents=True, exist_ok=True)

print("Estructura preparada.")

# %% [markdown]
# ## 1. Obtención de los datos
#
# **Pendiente:**
# - Documentar la fuente.
# - Registrar la fecha de extracción.
# - Descargar los datos de establecimientos con nivel Diversificado.
# - Guardar los archivos sin modificar en `data/raw/`.

# %%
# TODO: implementar la obtención de datos

# %% [markdown]
# ## 2. Unión de los archivos crudos
#
# **Pendiente:**
# - Verificar que los archivos tengan estructuras compatibles.
# - Unir la información de todos los departamentos.
# - Conservar evidencia de la cantidad de archivos y registros.

# %%
# TODO: cargar y unir los archivos crudos

# %% [markdown]
# ## 3. Diagnóstico inicial
#
# Incluir como mínimo:
# - Número de registros y variables.
# - Tipos de datos.
# - Valores faltantes y porcentajes.
# - Valores únicos.
# - Duplicados exactos.
# - Valores fuera de dominio.
# - Formatos inconsistentes.
# - Problemas potenciales de calidad.

# %%
# TODO: diagnóstico inicial sin modificar los datos

# %% [markdown]
# ## 4. Plan de limpieza

# %%
# TODO: cargar o mostrar el plan documentado en docs/plan_limpieza.md

# %% [markdown]
# ## 5. Limpieza reproducible

# %%
# TODO: aplicar las transformaciones definidas en el plan

# %% [markdown]
# ## 6. Registro de transformaciones

# %%
# TODO: consolidar el registro de transformaciones

# %% [markdown]
# ## 7. Validación automática

# %%
# TODO: ejecutar las pruebas de calidad

# %% [markdown]
# ## 8. Informe de calidad: antes y después

# %%
# TODO: construir la tabla comparativa

# %% [markdown]
# ## 9. Generación del conjunto limpio

# %%
# TODO: guardar un único CSV en data/processed/

# %% [markdown]
# ## 10. Conclusiones
